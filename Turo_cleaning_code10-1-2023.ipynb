# %%
import pandas as pd
import os

# %% [markdown]
# Import the entire folder and create a list of file paths for the individual csv files

# %%
#Innitiate an empty list to store the csv file paths
folder_path = r"D:\Data Scraping\Turo\Nashville\Octorber\Raw Excel"

file_paths = []

# List all files in the folder (excluding subdirectories)
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        file_paths.append(file_path)

# View the file paths
file_paths
# Out:
# ['D:\\Data Scraping\\Turo\\Nashville\\Octorber\\Raw Excel\\week15.csv',
#  'D:\\Data Scraping\\Turo\\Nashville\\Octorber\\Raw Excel\\week0.csv',
#  'D:\\Data Scraping\\Turo\\Nashville\\Octorber\\Raw Excel\\week2.csv',
#  'D:\\Data Scraping\\Turo\\Nashville\\Octorber\\Raw Excel\\week4.csv',
#  'D:\\Data Scraping\\Turo\\Nashville\\Octorber\\Raw Excel\\week6.csv',
#  'D:\\Data Scraping\\Turo\\Nashville\\Octorber\\Raw Excel\\week7.csv',
#  'D:\\Data Scraping\\Turo\\Nashville\\Octorber\\Raw Excel\\week8.csv',
#  'D:\\Data Scraping\\Turo\\Nashville\\Octorber\\Raw Excel\\week9.csv',
#  'D:\\Data Scraping\\Turo\\Nashville\\Octorber\\Raw Excel\\week10.csv',
#  'D:\\Data Scraping\\Turo\\Nashville\\Octorber\\Raw Excel\\week11.csv',
#  'D:\\Data Scraping\\Turo\\Nashville\\Octorber\\Raw Excel\\week12.csv',
#  'D:\\Data Scraping\\Turo\\Nashville\\Octorber\\Raw Excel\\week13.csv',
#  'D:\\Data Scraping\\Turo\\Nashville\\Octorber\\Raw Excel\\week14.csv']

# %% [markdown]
# ---
#
# Concatenating data frames

# %%
#Innitiate an empty list to store the data frames
cars_dfs = []

#Use the file paths to fill the list with data frames
for df in file_paths: 
    df = pd.read_csv(df)
    cars_dfs.append(df)

#Concatenate the data frames together
concat_df = pd.concat(cars_dfs)
concat_df
# Out:
#       vehicles.id  vehicles.completedTrips  vehicles.estimatedQuote  \
# 0         2190039                       10                      NaN
# 1         2182884                        6                      NaN
# 2         2181949                       10                      NaN
# 3         2160753                       12                      NaN
# 4         2099638                       19                      NaN
# ...           ...                      ...                      ...
# 6895      2119988                        7                      NaN
# 6896      1238451                       42                      NaN
# 6897      1453709                       14                      NaN
# 6898      2009218                       20                      NaN
# 6899      1510801                       47                      NaN
#
#       vehicles.hostId  vehicles.isAllStarHost  vehicles.isFavoritedBySearcher  \
# 0            24710785                   False                           False
# 1            24710785                   False                           False
# 2             6333177                   False                           False
# 3             5849654                   False                           False
# 4            24710785                   False                           False
# ...               ...                     ...                             ...
# 6895          4170304                   False                           False
# 6896          3742508                    True                           False
# 6897          7674610                   False                           False
# 6898          3742508                    True                           False
# 6899          3742508                    True                           False
#
#       vehicles.isNewListing  vehicles.make     vehicles.model  \
# 0                     False     Volkswagen               Taos
# 1                     False     Volkswagen             Tiguan
# 2                     False  Mercedes-Benz           GL-Class
# 3                     False     Volkswagen              Jetta
# 4                     False      Chevrolet           Suburban
# ...                     ...            ...                ...
# 6895                  False           Ford            Transit
# 6896                  False       Cadillac       Escalade ESV
# 6897                  False           Ford            Transit
# 6898                  False     Land Rover  Range Rover Sport
# 6899                  False       Cadillac       Escalade ESV
#
#       vehicles.rating  ... searchLocation.appliedRadius.unit  \
# 0                 5.0  ...                             MILES
# 1                 5.0  ...                             MILES
# 2                 5.0  ...                             MILES
# 3                 5.0  ...                             MILES
# 4                 5.0  ...                             MILES
# ...               ...  ...                               ...
# 6895              5.0  ...                             MILES
# 6896              5.0  ...                             MILES
# 6897              5.0  ...                             MILES
# 6898              5.0  ...                             MILES
# 6899              5.0  ...                             MILES
#
#       searchLocation.appliedRadius.value  searchLocation.point.lat  \
# 0                               6.430942                 36.180583
# 1                               6.430942                 36.180583
# 2                               6.430942                 36.180583
# 3                               6.430942                 36.180583
# 4                               6.430942                 36.180583
# ...                                  ...                       ...
# 6895                            2.229049                 36.216369
# 6896                            2.229049                 36.216369
# 6897                            2.229049                 36.216369
# 6898                            2.229049                 36.216369
# 6899                            2.229049                 36.216369
#
#      searchLocation.point.lng      searchLocation.topPois[0].name  \
# 0                  -86.804193  Music City Star Riverfront Station
# 1                  -86.804193  Music City Star Riverfront Station
# 2                  -86.804193  Music City Star Riverfront Station
# 3                  -86.804193  Music City Star Riverfront Station
# 4                  -86.804193  Music City Star Riverfront Station
# ...                       ...                                 ...
# 6895               -86.734417                                 NaN
# 6896               -86.734417                                 NaN
# 6897               -86.734417                                 NaN
# 6898               -86.734417                                 NaN
# 6899               -86.734417                                 NaN
#
#      searchLocation.topPois[0].locationId  \
# 0                               8558547.0
# 1                               8558547.0
# 2                               8558547.0
# 3                               8558547.0
# 4                               8558547.0
# ...                                   ...
# 6895                                  NaN
# 6896                                  NaN
# 6897                                  NaN
# 6898                                  NaN
# 6899                                  NaN
#
#       searchLocation.topPois[0].shortName  searchLocation.topPois[0].type  \
# 0                                     NaN                   TRAIN_STATION
# 1                                     NaN                   TRAIN_STATION
# 2                                     NaN                   TRAIN_STATION
# 3                                     NaN                   TRAIN_STATION
# 4                                     NaN                   TRAIN_STATION
# ...                                   ...                             ...
# 6895                                  NaN                             NaN
# 6896                                  NaN                             NaN
# 6897                                  NaN                             NaN
# 6898                                  NaN                             NaN
# 6899                                  NaN                             NaN
#
#      searchLocation.topPois[0].point.lat searchLocation.topPois[0].point.lng
# 0                               36.16214                            -86.7738
# 1                               36.16214                            -86.7738
# 2                               36.16214                            -86.7738
# 3                               36.16214                            -86.7738
# 4                               36.16214                            -86.7738
# ...                                  ...                                 ...
# 6895                                 NaN                                 NaN
# 6896                                 NaN                                 NaN
# 6897                                 NaN                                 NaN
# 6898                                 NaN                                 NaN
# 6899                                 NaN                                 NaN
#
# [86286 rows x 56 columns]

# %% [markdown]
# ---
#
# Filter columns

# %%
#Sub-set only the columns of interest
concat_df = concat_df[['vehicles.id', 
                      'vehicles.completedTrips',
                      'vehicles.hostId',
                      'vehicles.isAllStarHost',
                      'vehicles.isFavoritedBySearcher', 
                      'vehicles.isNewListing',
                      'vehicles.make',
                      'vehicles.model',
                      'vehicles.rating',
                      'vehicles.type',
                      'vehicles.year',
                      'vehicles.avgDailyPrice.amount',
                      'vehicles.location.city',
                      'vehicles.location.homeLocation.lat',
                      'vehicles.location.homeLocation.lng']]

concat_df
# Out:
#       vehicles.id  vehicles.completedTrips  vehicles.hostId  \
# 0         2190039                       10         24710785
# 1         2182884                        6         24710785
# 2         2181949                       10          6333177
# 3         2160753                       12          5849654
# 4         2099638                       19         24710785
# ...           ...                      ...              ...
# 6895      2119988                        7          4170304
# 6896      1238451                       42          3742508
# 6897      1453709                       14          7674610
# 6898      2009218                       20          3742508
# 6899      1510801                       47          3742508
#
#       vehicles.isAllStarHost  vehicles.isFavoritedBySearcher  \
# 0                      False                           False
# 1                      False                           False
# 2                      False                           False
# 3                      False                           False
# 4                      False                           False
# ...                      ...                             ...
# 6895                   False                           False
# 6896                    True                           False
# 6897                   False                           False
# 6898                    True                           False
# 6899                    True                           False
#
#       vehicles.isNewListing  vehicles.make     vehicles.model  \
# 0                     False     Volkswagen               Taos
# 1                     False     Volkswagen             Tiguan
# 2                     False  Mercedes-Benz           GL-Class
# 3                     False     Volkswagen              Jetta
# 4                     False      Chevrolet           Suburban
# ...                     ...            ...                ...
# 6895                  False           Ford            Transit
# 6896                  False       Cadillac       Escalade ESV
# 6897                  False           Ford            Transit
# 6898                  False     Land Rover  Range Rover Sport
# 6899                  False       Cadillac       Escalade ESV
#
#       vehicles.rating  vehicles.type  vehicles.year  \
# 0                 5.0            SUV           2022
# 1                 5.0            SUV           2021
# 2                 5.0            SUV           2014
# 3                 5.0            CAR           2023
# 4                 5.0            SUV           2018
# ...               ...            ...            ...
# 6895              5.0  PASSENGER_VAN           2020
# 6896              5.0            SUV           2021
# 6897              5.0  PASSENGER_VAN           2016
# 6898              5.0            SUV           2020
# 6899              5.0            SUV           2022
#
#       vehicles.avgDailyPrice.amount vehicles.location.city  \
# 0                             46.55              Nashville
# 1                             47.50              Nashville
# 2                             53.10              Nashville
# 3                             41.70              Nashville
# 4                             84.55              Nashville
# ...                             ...                    ...
# 6895                         170.00              Nashville
# 6896                         213.75              Nashville
# 6897                         175.00              Nashville
# 6898                         185.25              Nashville
# 6899                         225.00              Nashville
#
#       vehicles.location.homeLocation.lat  vehicles.location.homeLocation.lng
# 0                              36.151284                          -86.664557
# 1                              36.151284                          -86.664557
# 2                              36.151284                          -86.664557
# 3                              36.203585                          -86.692441
# 4                              36.151284                          -86.664557
# ...                                  ...                                 ...
# 6895                           36.242320                          -86.701868
# 6896                           36.248488                          -86.721755
# 6897                           36.232708                          -86.756256
# 6898                           36.246942                          -86.721644
# 6899                           36.246942                          -86.721644
#
# [86286 rows x 15 columns]

# %% [markdown]
# ---
#
# Rename columns

# %%
#Create new column names
new_column_names = {'vehicles.id':'id', 
                      'vehicles.completedTrips':'trips_oct2023',
                      'vehicles.hostId':'host_id_oct2023',
                      'vehicles.isAllStarHost':'all_star_host_oct2023',
                      'vehicles.isFavoritedBySearcher':'favorited_by_searcher_oct2023', 
                      'vehicles.isNewListing':'new_listing_oct2023',
                      'vehicles.make':'make_oct2023',
                      'vehicles.model':'model_oct2023',
                      'vehicles.rating':'rating_oct2023',
                      'vehicles.type':'type_oct2023',
                      'vehicles.year':'year_oct2023',
                      'vehicles.avgDailyPrice.amount':'price_per_day_oct2023',
                      'vehicles.location.city':'city_oct2023',
                      'vehicles.location.homeLocation.lat':'lat_oct2023',
                      'vehicles.location.homeLocation.lng':'lng_oct2023'}

#Apply new column names
new_df = concat_df.rename(columns=new_column_names)
new_df
# Out:
#            id  trips_oct2023  host_id_oct2023  all_star_host_oct2023  \
# 0     2190039             10         24710785                  False
# 1     2182884              6         24710785                  False
# 2     2181949             10          6333177                  False
# 3     2160753             12          5849654                  False
# 4     2099638             19         24710785                  False
# ...       ...            ...              ...                    ...
# 6895  2119988              7          4170304                  False
# 6896  1238451             42          3742508                   True
# 6897  1453709             14          7674610                  False
# 6898  2009218             20          3742508                   True
# 6899  1510801             47          3742508                   True
#
#       favorited_by_searcher_oct2023  new_listing_oct2023   make_oct2023  \
# 0                             False                False     Volkswagen
# 1                             False                False     Volkswagen
# 2                             False                False  Mercedes-Benz
# 3                             False                False     Volkswagen
# 4                             False                False      Chevrolet
# ...                             ...                  ...            ...
# 6895                          False                False           Ford
# 6896                          False                False       Cadillac
# 6897                          False                False           Ford
# 6898                          False                False     Land Rover
# 6899                          False                False       Cadillac
#
#           model_oct2023  rating_oct2023   type_oct2023  year_oct2023  \
# 0                  Taos             5.0            SUV          2022
# 1                Tiguan             5.0            SUV          2021
# 2              GL-Class             5.0            SUV          2014
# 3                 Jetta             5.0            CAR          2023
# 4              Suburban             5.0            SUV          2018
# ...                 ...             ...            ...           ...
# 6895            Transit             5.0  PASSENGER_VAN          2020
# 6896       Escalade ESV             5.0            SUV          2021
# 6897            Transit             5.0  PASSENGER_VAN          2016
# 6898  Range Rover Sport             5.0            SUV          2020
# 6899       Escalade ESV             5.0            SUV          2022
#
#       price_per_day_oct2023 city_oct2023  lat_oct2023  lng_oct2023
# 0                     46.55    Nashville    36.151284   -86.664557
# 1                     47.50    Nashville    36.151284   -86.664557
# 2                     53.10    Nashville    36.151284   -86.664557
# 3                     41.70    Nashville    36.203585   -86.692441
# 4                     84.55    Nashville    36.151284   -86.664557
# ...                     ...          ...          ...          ...
# 6895                 170.00    Nashville    36.242320   -86.701868
# 6896                 213.75    Nashville    36.248488   -86.721755
# 6897                 175.00    Nashville    36.232708   -86.756256
# 6898                 185.25    Nashville    36.246942   -86.721644
# 6899                 225.00    Nashville    36.246942   -86.721644
#
# [86286 rows x 15 columns]

# %% [markdown]
# ---
#
# Remove duplicates

# %%
unique_data = new_df.drop_duplicates()

unique_data
# Out:
#            id  trips_oct2023  host_id_oct2023  all_star_host_oct2023  \
# 0     2190039             10         24710785                  False
# 1     2182884              6         24710785                  False
# 2     2181949             10          6333177                  False
# 3     2160753             12          5849654                  False
# 4     2099638             19         24710785                  False
# ...       ...            ...              ...                    ...
# 6409  2029372              7         20314208                   True
# 6412  2224082              0         37523578                  False
# 6430  1533205             23         24550587                   True
# 6439  2200262              0         35908584                  False
# 6522  2161554              1         35323298                  False
#
#       favorited_by_searcher_oct2023  new_listing_oct2023   make_oct2023  \
# 0                             False                False     Volkswagen
# 1                             False                False     Volkswagen
# 2                             False                False  Mercedes-Benz
# 3                             False                False     Volkswagen
# 4                             False                False      Chevrolet
# ...                             ...                  ...            ...
# 6409                          False                False          Honda
# 6412                          False                 True          Mazda
# 6430                          False                False       Cadillac
# 6439                          False                False            Ram
# 6522                          False                False         Toyota
#
#      model_oct2023  rating_oct2023       type_oct2023  year_oct2023  \
# 0             Taos          5.0000                SUV          2022
# 1           Tiguan          5.0000                SUV          2021
# 2         GL-Class          5.0000                SUV          2014
# 3            Jetta          5.0000                CAR          2023
# 4         Suburban          5.0000                SUV          2018
# ...            ...             ...                ...           ...
# 6409       Odyssey          4.7143  PASSENGER_MINIVAN          2015
# 6412          CX-9             NaN                SUV          2022
# 6430           SRX          5.0000                SUV          2012
# 6439          2500             NaN              TRUCK          2016
# 6522       Corolla          5.0000                CAR          2022
#
#       price_per_day_oct2023    city_oct2023  lat_oct2023  lng_oct2023
# 0                     46.55       Nashville    36.151284   -86.664557
# 1                     47.50       Nashville    36.151284   -86.664557
# 2                     53.10       Nashville    36.151284   -86.664557
# 3                     41.70       Nashville    36.203585   -86.692441
# 4                     84.55       Nashville    36.151284   -86.664557
# ...                     ...             ...          ...          ...
# 6409                  49.09  Hendersonville    36.302616   -86.638157
# 6412                  56.74  Hendersonville    36.302253   -86.636318
# 6430                  49.64  Hendersonville    36.331782   -86.584742
# 6439                  57.38  Hendersonville    36.260238   -86.624095
# 6522                  44.63  Goodlettsville    36.318232   -86.719923
#
# [4948 rows x 15 columns]

# %% [markdown]
# ---
#
# Find the total amount of unique values in the 'id' column

# %%
unique_data[['id']].drop_duplicates()
# Out:
#            id
# 0     2190039
# 1     2182884
# 2     2181949
# 3     2160753
# 4     2099638
# ...       ...
# 4630  1963906
# 5003  2156761
# 4697  2131727
# 4743  2104896
# 4028  1735294
#
# [1038 rows x 1 columns]

# %% [markdown]
# ---
#
# Average the price

# %%
#Group by id and return a df with averge price for each id
join1 = unique_data.groupby('id')['price_per_day_oct2023'].agg(average_price='mean').reset_index()

#Remove the price column from the original df and drop the duplicates
join2 = unique_data.drop(columns = ['price_per_day_oct2023']).drop_duplicates()

#Join the average price df to the original df
final_clean = pd.merge(join1, join2, how = 'inner', on = 'id')

final_clean = final_clean.rename(columns = {'average_price' : 'average_price_oct2023'})

final_clean
# Out:
#            id  average_price_oct2023  trips_oct2023  host_id_oct2023  \
# 0      301046              43.585000            236          1311189
# 1      370101             515.375000              6          5082554
# 2      386843              91.000000            221          3293037
# 3      429041             200.166667            102          4112200
# 4      462620              94.344000             53          5917679
# ...       ...                    ...            ...              ...
# 1088  2359251              71.250000              0         23255376
# 1089  2359437              33.600000              0         35337343
# 1090  2359467              46.447500              0          9753934
# 1091  2359745              49.500000              0         20855530
# 1092  2360761             101.375000              0          3742508
#
#       all_star_host_oct2023  favorited_by_searcher_oct2023  \
# 0                     False                          False
# 1                     False                          False
# 2                      True                          False
# 3                      True                          False
# 4                      True                          False
# ...                     ...                            ...
# 1088                  False                          False
# 1089                  False                          False
# 1090                   True                          False
# 1091                  False                          False
# 1092                   True                          False
#
#       new_listing_oct2023 make_oct2023          model_oct2023  rating_oct2023  \
# 0                   False       Toyota                  Camry          4.9116
# 1                   False      Porsche                    911          5.0000
# 2                   False         Jeep  Wrangler JK Unlimited          5.0000
# 3                   False       Jaguar                 F-TYPE          5.0000
# 4                   False        Lexus                     IS          4.9063
# ...                   ...          ...                    ...             ...
# 1088                 True          BMW                     X3             NaN
# 1089                 True    Chevrolet                  Sonic             NaN
# 1090                 True       Toyota                  Camry             NaN
# 1091                 True     Chrysler         Town & Country             NaN
# 1092                 True        Dodge                Charger             NaN
#
#            type_oct2023  year_oct2023 city_oct2023  lat_oct2023  lng_oct2023
# 0                   CAR          2012    Nashville    36.089184   -86.920420
# 1                   CAR          2014    Nashville    36.095788   -86.681452
# 2                   SUV          2018    Brentwood    36.024075   -86.748148
# 3                   CAR          2018    Brentwood    36.042198   -86.767288
# 4                   CAR          2010    Nashville    36.190869   -86.811879
# ...                 ...           ...          ...          ...          ...
# 1088                SUV          2013    Nashville    36.157021   -86.766259
# 1089                CAR          2018      Lebanon    36.188721   -86.400539
# 1090                CAR          2012    Nashville    36.156132   -86.665867
# 1091  PASSENGER_MINIVAN          2016    Nashville    36.054055   -86.616648
# 1092                CAR          2023    Nashville    36.246942   -86.721644
#
# [1093 rows x 15 columns]

# %% [markdown]
# ---
#
# Average the rating

# %%
#Group by id and return a df with averge trip rating for each id
join1 = final_clean.groupby('id')['rating_oct2023'].agg(average_rating='mean').reset_index()

#Remove the rating column from the original df and drop the duplicates
join2 = final_clean.drop(columns = ['rating_oct2023']).drop_duplicates()

#Join the average rating df to the original df
final_clean = pd.merge(join1, join2, how = 'inner', on = 'id')

final_clean = final_clean.rename(columns = {'average_rating' : 'average_rating_oct2023'})

final_clean
# Out:
#            id  average_rating_oct2023  average_price_oct2023  trips_oct2023  \
# 0      301046                  4.9116              43.585000            236
# 1      370101                  5.0000             515.375000              6
# 2      386843                  5.0000              91.000000            221
# 3      429041                  5.0000             200.166667            102
# 4      462620                  4.9063              94.344000             53
# ...       ...                     ...                    ...            ...
# 1077  2359251                     NaN              71.250000              0
# 1078  2359437                     NaN              33.600000              0
# 1079  2359467                     NaN              46.447500              0
# 1080  2359745                     NaN              49.500000              0
# 1081  2360761                     NaN             101.375000              0
#
#       host_id_oct2023  all_star_host_oct2023  favorited_by_searcher_oct2023  \
# 0             1311189                  False                          False
# 1             5082554                  False                          False
# 2             3293037                   True                          False
# 3             4112200                   True                          False
# 4             5917679                   True                          False
# ...               ...                    ...                            ...
# 1077         23255376                  False                          False
# 1078         35337343                  False                          False
# 1079          9753934                   True                          False
# 1080         20855530                  False                          False
# 1081          3742508                   True                          False
#
#       new_listing_oct2023 make_oct2023          model_oct2023  \
# 0                   False       Toyota                  Camry
# 1                   False      Porsche                    911
# 2                   False         Jeep  Wrangler JK Unlimited
# 3                   False       Jaguar                 F-TYPE
# 4                   False        Lexus                     IS
# ...                   ...          ...                    ...
# 1077                 True          BMW                     X3
# 1078                 True    Chevrolet                  Sonic
# 1079                 True       Toyota                  Camry
# 1080                 True     Chrysler         Town & Country
# 1081                 True        Dodge                Charger
#
#            type_oct2023  year_oct2023 city_oct2023  lat_oct2023  lng_oct2023
# 0                   CAR          2012    Nashville    36.089184   -86.920420
# 1                   CAR          2014    Nashville    36.095788   -86.681452
# 2                   SUV          2018    Brentwood    36.024075   -86.748148
# 3                   CAR          2018    Brentwood    36.042198   -86.767288
# 4                   CAR          2010    Nashville    36.190869   -86.811879
# ...                 ...           ...          ...          ...          ...
# 1077                SUV          2013    Nashville    36.157021   -86.766259
# 1078                CAR          2018      Lebanon    36.188721   -86.400539
# 1079                CAR          2012    Nashville    36.156132   -86.665867
# 1080  PASSENGER_MINIVAN          2016    Nashville    36.054055   -86.616648
# 1081                CAR          2023    Nashville    36.246942   -86.721644
#
# [1082 rows x 15 columns]

# %% [markdown]
# ---
#
# If one car has two different values for 'trips', then take the larger one

# %%
#Group by id and return a df with max trips for each id
join1 = final_clean.groupby('id')['trips_oct2023'].max().reset_index()

#Remove the trips column from the original df and drop the duplicates
join2 = final_clean.drop(columns = ['trips_oct2023']).drop_duplicates()

#Join the trips df to the original df
final_clean = pd.merge(join1, join2, how = 'inner', on = 'id')

final_clean = final_clean.rename(columns = {'trips' : 'trips_oct2023'})

final_clean
# Out:
#            id  trips_oct2023  average_rating_oct2023  average_price_oct2023  \
# 0      301046            236                  4.9116              43.585000
# 1      370101              6                  5.0000             515.375000
# 2      386843            221                  5.0000              91.000000
# 3      429041            102                  5.0000             200.166667
# 4      462620             53                  4.9063              94.344000
# ...       ...            ...                     ...                    ...
# 1033  2359251              0                     NaN              71.250000
# 1034  2359437              0                     NaN              33.600000
# 1035  2359467              0                     NaN              46.447500
# 1036  2359745              0                     NaN              49.500000
# 1037  2360761              0                     NaN             101.375000
#
#       host_id_oct2023  all_star_host_oct2023  favorited_by_searcher_oct2023  \
# 0             1311189                  False                          False
# 1             5082554                  False                          False
# 2             3293037                   True                          False
# 3             4112200                   True                          False
# 4             5917679                   True                          False
# ...               ...                    ...                            ...
# 1033         23255376                  False                          False
# 1034         35337343                  False                          False
# 1035          9753934                   True                          False
# 1036         20855530                  False                          False
# 1037          3742508                   True                          False
#
#       new_listing_oct2023 make_oct2023          model_oct2023  \
# 0                   False       Toyota                  Camry
# 1                   False      Porsche                    911
# 2                   False         Jeep  Wrangler JK Unlimited
# 3                   False       Jaguar                 F-TYPE
# 4                   False        Lexus                     IS
# ...                   ...          ...                    ...
# 1033                 True          BMW                     X3
# 1034                 True    Chevrolet                  Sonic
# 1035                 True       Toyota                  Camry
# 1036                 True     Chrysler         Town & Country
# 1037                 True        Dodge                Charger
#
#            type_oct2023  year_oct2023 city_oct2023  lat_oct2023  lng_oct2023
# 0                   CAR          2012    Nashville    36.089184   -86.920420
# 1                   CAR          2014    Nashville    36.095788   -86.681452
# 2                   SUV          2018    Brentwood    36.024075   -86.748148
# 3                   CAR          2018    Brentwood    36.042198   -86.767288
# 4                   CAR          2010    Nashville    36.190869   -86.811879
# ...                 ...           ...          ...          ...          ...
# 1033                SUV          2013    Nashville    36.157021   -86.766259
# 1034                CAR          2018      Lebanon    36.188721   -86.400539
# 1035                CAR          2012    Nashville    36.156132   -86.665867
# 1036  PASSENGER_MINIVAN          2016    Nashville    36.054055   -86.616648
# 1037                CAR          2023    Nashville    36.246942   -86.721644
#
# [1038 rows x 15 columns]

# %% [markdown]
# ---
#
# Filter for only cities of interest

# %%
final_clean['city_oct2023'].unique()
# Out:
# array(['Nashville', 'Brentwood', 'Aurora', 'Murfreesboro',
#        'Hendersonville', 'Franklin', 'Smyrna', 'Greenbrier',
#        'Spring Hill', 'Gallatin', 'Goodlettsville', 'Lebanon',
#        'Hermitage', 'Christiana', 'Antioch', 'Mt. Juliet', 'Lascassas',
#        'La Vergne', 'Mount Juliet', 'Columbia', 'Forest Hills',
#        "Thompson's Station", 'Nolensville', 'Arrington', 'White House',
#        'Beechgrove', 'Clarksville', 'Lavergne', 'Shelbyville', 'Pegram',
#        'Mt Juliet', 'Manchester', 'Whites Creek', 'Silver Point',
#        'Ashland City'], dtype=object)

# %%
#Create a list of cities to keep in the dataset
cities_to_keep = ['Nashville', 'Brentwood', 'Murfreesboro',
       'Hendersonville', 'Franklin', 'Smyrna', 'Goodlettsville',
       'Hermitage', 'Antioch', 'Mt. Juliet',
       'La Vergne', 'Mount Juliet', 'Forest Hills', 'Nolensville', 'Arrington', 'Lavergne',
       'Mt Juliet', 'Whites Creek']

#Filter for only the cities of interest
final_clean = final_clean[final_clean['city_oct2023'].isin(cities_to_keep)]

# %%
final_clean['city_oct2023'].unique()
# Out:
# array(['Nashville', 'Brentwood', 'Murfreesboro', 'Hendersonville',
#        'Franklin', 'Smyrna', 'Goodlettsville', 'Hermitage', 'Antioch',
#        'Mt. Juliet', 'La Vergne', 'Mount Juliet', 'Forest Hills',
#        'Nolensville', 'Arrington', 'Lavergne', 'Mt Juliet',
#        'Whites Creek'], dtype=object)

# %% [markdown]
# ---
#
# Rename columns

# %%
#Create a dictionary with new names
value_mapping = {'Mt. Juliet':'Mount Juliet',
                 'Mt Juliet':'Mount Juliet',
                 'Forest Hills':'Nashville',
                'Antioch':'Nashville',
                'Whites Creek':'Nashville',
                'Hermitage':'Nashville',
                'Lavergne':'La Vergne'}

#Apply the new names to the city column
final_clean.loc[final_clean['city_oct2023'].isin(value_mapping.keys()), 'city_oct2023'] = final_clean['city_oct2023'].replace(value_mapping)

# %%
final_clean['city_oct2023'].unique()
# Out:
# array(['Nashville', 'Brentwood', 'Murfreesboro', 'Hendersonville',
#        'Franklin', 'Smyrna', 'Goodlettsville', 'Mount Juliet',
#        'La Vergne', 'Nolensville', 'Arrington'], dtype=object)

# %% [markdown]
# ---
#
# Export file to excel

# %%
final_clean.to_excel(r"D:\Data Scraping\Turo\Nashville\Octorber\Clean Data\clean_data.xlsx", index = False)
